# %%
cd scripts
# Out:
# /home/airlab/ws_yuthDev/ws_2f/src/robotiq_2f_gripper/scripts

# %%
from gripper_driver import gg

# %%
g = gg()
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
g.deactivate_emergency_release()
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
g.sendCommand()
# Out:
# SEND COMMAND
# True

# %%
g.activate()
# Out:
# [1, 0, 0, 0, 255, 150]

# %%
g.deactivate()
# Out:
# [0, 0, 0, 0, 255, 150]

# %%
g.goto(255,0,0)
# Out:
# [9, 0, 0, 255, 0, 0]

# %%
g.goto(0,0,0)
# Out:
# [9, 0, 0, 0, 0, 0]
